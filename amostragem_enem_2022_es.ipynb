# %% [markdown]
# ## **AMOSTRAGENS**

# %%
import numpy as np
import pandas as pd

# %%
enem_es = pd.read_csv('enem_2022_es_tratado.csv', sep=',', encoding='iso-8859-1')

# %%
enem_es.head()
# Out:
#   NU_INSCRICAO FAIXA_ETARIA SEXO  ESTADO_CIVIL   RACA  NACIONALIDADE  \
# 0     2,10E+11           21    M             1  parda              1
# 1     2,10E+11           19    F             1  parda              1
# 2     2,10E+11           17    F             1  parda              1
# 3     2,10E+11        41_45    F             3  parda              1
# 4     2,10E+11           17    M             1  parda              1
#
#    TP_ST_CONCLUSAO         ESCOLA NO_MUNICIPIO_ESC NO_MUNICIPIO_PROVA  ...  \
# 0                1  nao_respondeu              NaN          Cariacica  ...
# 1                1  nao_respondeu              NaN           Colatina  ...
# 2                2        privada              NaN           Colatina  ...
# 3                1  nao_respondeu              NaN         Vila Velha  ...
# 4                2        publica            Viana          Cariacica  ...
#
#    NOTA_MT  TP_LINGUA  TP_STATUS_REDACAO  COMP1  COMP2  COMP3  COMP4  COMP5  \
# ...

# %%
enem_serra = enem_es.loc[enem_es.NO_MUNICIPIO_PROVA == 'Serra']

# %%
enem_serra.head(10)
# Out:
#    NU_INSCRICAO FAIXA_ETARIA SEXO  ESTADO_CIVIL    RACA  NACIONALIDADE  \
# 6      2,10E+11        31_35    F             1   parda              1
# 17     2,10E+11        31_35    F             1   parda              1
# 45     2,10E+11           18    F             1  branca              1
# 49     2,10E+11           21    F             1  branca              1
# 53     2,10E+11           18    F             1   parda              1
# 69     2,10E+11           25    F             1  branca              1
# 70     2,10E+11           18    F             1   preta              1
# 72     2,10E+11           18    F             1  branca              1
# 77     2,10E+11           18    F             1   preta              1
# 85     2,10E+11           22    F             1  branca              1
#
#     TP_ST_CONCLUSAO         ESCOLA NO_MUNICIPIO_ESC NO_MUNICIPIO_PROVA  ...  \
# 6                 1  nao_respondeu              NaN              Serra  ...
# ...

# %%
enem_serra.shape
# Out:
# (1476, 27)

# %% [markdown]
# ## Amostragem Aleatória Simples

# %%
# usando a seed fixamos a amostra selecionada
np.random.seed(1)

# %%
amos_simples = enem_serra.sample(frac=0.20) # definindo uma porcentagem

# %%
amos_simples
# Out:
#       NU_INSCRICAO FAIXA_ETARIA SEXO  ESTADO_CIVIL   RACA  NACIONALIDADE  \
# 4709      2,10E+11           18    M             1  parda              1
# 3271      2,10E+11           21    F             1  preta              1
# 6450      2,10E+11           17    F             1  parda              1
# 2829      2,10E+11           17    F             1  parda              1
# 7732      2,10E+11           18    F             1  parda              1
# ...            ...          ...  ...           ...    ...            ...
# 4066      2,10E+11           18    F             1  parda              1
# 2368      2,10E+11        26_30    F             1  preta              1
# 10100     2,10E+11           18    F             1  parda              1
# 9507      2,10E+11        31_35    F             3  parda              1
# 2492      2,10E+11           19    F             1  preta              1
#
#        TP_ST_CONCLUSAO         ESCOLA NO_MUNICIPIO_ESC NO_MUNICIPIO_PROVA  \
# ...

# %%
amos_simples = enem_serra.sample(300) # definindo uma quantidade numérica

# %%
amos_simples
# Out:
#       NU_INSCRICAO FAIXA_ETARIA SEXO  ESTADO_CIVIL    RACA  NACIONALIDADE  \
# 1791      2,10E+11           21    F             1   preta              1
# 7466      2,10E+11        41_45    F             2   parda              1
# 2558      2,10E+11           19    M             1   parda              1
# 6113      2,10E+11           18    F             1   preta              1
# 10648     2,10E+11           21    F             1   preta              1
# ...            ...          ...  ...           ...     ...            ...
# 1710      2,10E+11           19    F             1  branca              1
# 2450      2,10E+11           18    F             1   parda              1
# 7661      2,10E+11           18    M             3  branca              1
# 8408      2,10E+11           23    F             1   parda              1
# 9870      2,10E+11           19    M             1   parda              1
#
#        TP_ST_CONCLUSAO         ESCOLA NO_MUNICIPIO_ESC NO_MUNICIPIO_PROVA  \
# ...

# %% [markdown]
# #### OUTRA MANEIRA

# %%
np.random.seed(2)

# %%
amostra = np.random.choice(a=[0,1], size=1476, replace=True, p=[0.8, 0.2])

# %%
amostra
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
len(amostra[amostra == 0])
# Out:
# 1179

# %%
len(amostra[amostra == 1])
# Out:
# 297

# %%
amos_simples = enem_serra.loc[amostra == 1]

# %%
amos_simples
# Out:
#       NU_INSCRICAO FAIXA_ETARIA SEXO  ESTADO_CIVIL    RACA  NACIONALIDADE  \
# 125       2,10E+11           18    F             1  branca              1
# 133       2,10E+11           21    F             1   preta              1
# 236       2,10E+11           17    F             1  branca              1
# 255       2,10E+11           19    F             1   parda              1
# 280       2,10E+11           18    F             1  branca              1
# ...            ...          ...  ...           ...     ...            ...
# 11613     2,10E+11           20    M             1  branca              1
# 11660     2,10E+11           24    F             1   parda              1
# 11697     2,10E+11           18    F             1   parda              1
# 11709     2,10E+11           22    F             1   parda              1
# 11789     2,10E+11        41_45    F             1   parda              1
#
#        TP_ST_CONCLUSAO         ESCOLA NO_MUNICIPIO_ESC NO_MUNICIPIO_PROVA  \
# ...

# %% [markdown]
# ## Amostragem Sistemática

# %%
enem_serra.shape
# Out:
# (1476, 27)

# %%
np.random.seed(2)
inicio = np.random.choice(10, 1)

# %%
inicio
# Out:
# array([8])

# %%
amostra2 = np.arange(inicio,1476,10)
amostra2
# Out:
# array([   8,   18,   28,   38,   48,   58,   68,   78,   88,   98,  108,
#         118,  128,  138,  148,  158,  168,  178,  188,  198,  208,  218,
#         228,  238,  248,  258,  268,  278,  288,  298,  308,  318,  328,
#         338,  348,  358,  368,  378,  388,  398,  408,  418,  428,  438,
#         448,  458,  468,  478,  488,  498,  508,  518,  528,  538,  548,
#         558,  568,  578,  588,  598,  608,  618,  628,  638,  648,  658,
#         668,  678,  688,  698,  708,  718,  728,  738,  748,  758,  768,
#         778,  788,  798,  808,  818,  828,  838,  848,  858,  868,  878,
#         888,  898,  908,  918,  928,  938,  948,  958,  968,  978,  988,
#         998, 1008, 1018, 1028, 1038, 1048, 1058, 1068, 1078, 1088, 1098,
#        1108, 1118, 1128, 1138, 1148, 1158, 1168, 1178, 1188, 1198, 1208,
#        1218, 1228, 1238, 1248, 1258, 1268, 1278, 1288, 1298, 1308, 1318,
#        1328, 1338, 1348, 1358, 1368, 1378, 1388, 1398, 1408, 1418, 1428,
# ...

# %%
amos_sistematica = enem_serra.iloc[amostra2,:]

# %%
amos_sistematica
# Out:
#       NU_INSCRICAO FAIXA_ETARIA SEXO  ESTADO_CIVIL    RACA  NACIONALIDADE  \
# 77        2,10E+11           18    F             1   preta              1
# 133       2,10E+11           21    F             1   preta              1
# 195       2,10E+11           20    F             1   parda              1
# 230       2,10E+11           18    M             1   parda              1
# 267       2,10E+11           18    F             1   parda              1
# ...            ...          ...  ...           ...     ...            ...
# 11409     2,10E+11           23    M             1   parda              1
# 11500     2,10E+11           22    M             1  branca              1
# 11591     2,10E+11        36_40    F             0   parda              1
# 11697     2,10E+11           18    F             1   parda              1
# 11759     2,10E+11        36_40    F             1   parda              1
#
#        TP_ST_CONCLUSAO         ESCOLA NO_MUNICIPIO_ESC NO_MUNICIPIO_PROVA  \
# ...

# %% [markdown]
# #### OUTRA MANEIRA

# %%
np.random.seed(10)

# %%
inicio = np.random.choice(10, 1)
passo = np.random.randint(10, 15, 1)

# %%
inicio
# Out:
# array([9])

# %%
passo
# Out:
# array([14])

# %%
amostra2 = np.arange(inicio,1476,passo)
amostra2
# Out:
# array([   9,   23,   37,   51,   65,   79,   93,  107,  121,  135,  149,
#         163,  177,  191,  205,  219,  233,  247,  261,  275,  289,  303,
#         317,  331,  345,  359,  373,  387,  401,  415,  429,  443,  457,
#         471,  485,  499,  513,  527,  541,  555,  569,  583,  597,  611,
#         625,  639,  653,  667,  681,  695,  709,  723,  737,  751,  765,
#         779,  793,  807,  821,  835,  849,  863,  877,  891,  905,  919,
#         933,  947,  961,  975,  989, 1003, 1017, 1031, 1045, 1059, 1073,
#        1087, 1101, 1115, 1129, 1143, 1157, 1171, 1185, 1199, 1213, 1227,
#        1241, 1255, 1269, 1283, 1297, 1311, 1325, 1339, 1353, 1367, 1381,
#        1395, 1409, 1423, 1437, 1451, 1465])

# %%
amostra2_camp = enem_serra.iloc[amostra2,:]

# %%
amostra2_camp
# Out:
#       NU_INSCRICAO FAIXA_ETARIA SEXO  ESTADO_CIVIL    RACA  NACIONALIDADE  \
# 85        2,10E+11           22    F             1  branca              1
# 173       2,10E+11           17    F             1   parda              1
# 228       2,10E+11        31_35    M             2   preta              1
# 306       2,10E+11           17    F             1   preta              1
# 470       2,10E+11           19    M             1  branca              1
# ...            ...          ...  ...           ...     ...            ...
# 11229     2,10E+11        31_35    F             1  branca              1
# 11384     2,10E+11           18    F             1   parda              1
# 11493     2,10E+11           20    F             1   parda              1
# 11608     2,10E+11           18    F             1   preta              1
# 11729     2,10E+11           17    F             1   parda              1
#
#        TP_ST_CONCLUSAO         ESCOLA NO_MUNICIPIO_ESC NO_MUNICIPIO_PROVA  \
# ...

# %% [markdown]
# ## Amostragem Estratificada

# %%
enem_serra['RACA'].value_counts()
# Out:
# parda            748
# branca           421
# preta            259
# amarela           24
# nao_declarado     17
# indigena           7
# Name: RACA, dtype: int64

# %% [markdown]
# **Para quantidade pequena de grupos**

# %%
branca = enem_serra.loc[enem_serra.RACA == 'branca'].sample(frac=0.20)
branca.shape
# Out:
# (84, 27)

# %%
parda = enem_serra.loc[enem_serra.RACA == 'parda'].sample(frac=0.20)
parda.shape
# Out:
# (150, 27)

# %%
preta = enem_serra.loc[enem_serra.RACA == 'preta'].sample(frac=0.20)
preta.shape
# Out:
# (52, 27)

# %%
amarela = enem_serra.loc[enem_serra.RACA == 'amarela'].sample(frac=0.20)
amarela.shape
# Out:
# (5, 27)

# %%
nd = enem_serra.loc[enem_serra.RACA == 'nao_declarado'].sample(frac=0.20)
nd.shape
# Out:
# (3, 27)

# %%
indigena = enem_serra.loc[enem_serra.RACA == 'indigena'].sample(frac=0.20)
indigena.shape
# Out:
# (1, 27)

# %%
amos_estra = pd.concat([branca, parda, preta, amarela, nd, indigena])

# %%
amos_estra
# Out:
#       NU_INSCRICAO FAIXA_ETARIA SEXO  ESTADO_CIVIL           RACA  \
# 11122     2,10E+11           20    M             1         branca
# 11366     2,10E+11           20    M             1         branca
# 1199      2,10E+11           17    M             1         branca
# 4451      2,10E+11           18    F             1         branca
# 6589      2,10E+11           19    F             1         branca
# ...            ...          ...  ...           ...            ...
# 5293      2,10E+11           17    M             1        amarela
# 11401     2,10E+11        31_35    F             1  nao_declarado
# 7407      2,10E+11           18    F             1  nao_declarado
# 6681      2,10E+11           19    F             1  nao_declarado
# 11377     2,10E+11           21    M             1       indigena
#
#        NACIONALIDADE  TP_ST_CONCLUSAO         ESCOLA NO_MUNICIPIO_ESC  \
# 11122              2                1  nao_respondeu              NaN
# ...

# %% [markdown]
# #### Grandes quantidades de grupos

# %%
from sklearn.model_selection import train_test_split

# %%
X_treino, X_teste, y_treino, amos_estra = train_test_split(enem_serra.drop('RACA',axis=1),enem_serra['RACA'],
                                                    stratify=enem_serra['RACA'], test_size=0.20)

# %%
amos_estra.shape
# Out:
# (296,)

# %%
amos_estra.value_counts()
# Out:
# parda            150
# branca            85
# preta             52
# amarela            5
# nao_declarado      3
# indigena           1
# Name: RACA, dtype: int64

# %%
amos_estra = amos_estra.index

# %%
amos_estra
# Out:
# Int64Index([ 2343,  3674,  4372,  4412,  1132,  5059,  8056,  7985,  2060,
#             10727,
#             ...
#              9278,  3866,  3169,  4899,  7817,  5920,  2279, 11488,  9848,
#              3271],
#            dtype='int64', length=296)

# %%
amos_estra_serra = enem_serra.loc[amos_estra,:]

# %%
amos_estra_serra
# Out:
#       NU_INSCRICAO FAIXA_ETARIA SEXO  ESTADO_CIVIL     RACA  NACIONALIDADE  \
# 2343      2,10E+11           17    M             1    parda              1
# 3674      2,10E+11        31_35    F             2   branca              1
# 4372      2,10E+11           17    F             1    parda              1
# 4412      2,10E+11           18    F             1    preta              1
# 1132      2,10E+11           21    F             1    parda              1
# ...            ...          ...  ...           ...      ...            ...
# 5920      2,10E+11           18    M             3    parda              1
# 2279      2,10E+11           17    F             1  amarela              1
# 11488     2,10E+11           18    M             1    parda              1
# 9848      2,10E+11           19    M             1    parda              1
# 3271      2,10E+11           21    F             1    preta              1
#
# ...

# %% [markdown]
# ## Amostragem por Conglomerado (agrupamento)

# %%
escolas_publicas = enem_serra.loc[enem_serra.ESCOLA == 'publica']

# %%
escolas_publicas.shape
# Out:
# (713, 27)

# %%
escolas_publicas
# Out:
#       NU_INSCRICAO FAIXA_ETARIA SEXO  ESTADO_CIVIL    RACA  NACIONALIDADE  \
# 53        2,10E+11           18    F             1   parda              1
# 70        2,10E+11           18    F             1   preta              1
# 72        2,10E+11           18    F             1  branca              1
# 77        2,10E+11           18    F             1   preta              1
# 94        2,10E+11        26_30    F             0   parda              1
# ...            ...          ...  ...           ...     ...            ...
# 11712     2,10E+11           17    F             1   parda              1
# 11729     2,10E+11           17    F             1   parda              1
# 11762     2,10E+11           18    M             1   parda              1
# 11770     2,10E+11           17    M             1  branca              1
# 11813     2,10E+11           17    F             1   parda              1
#
#        TP_ST_CONCLUSAO   ESCOLA NO_MUNICIPIO_ESC NO_MUNICIPIO_PROVA  ...  \
# ...

# %%
amostras = escolas_publicas['NO_MUNICIPIO_ESC'].value_counts()
amostras
# Out:
# Serra           378
# Vitória          92
# Santa Teresa      7
# Aracruz           5
# Vila Velha        3
# Cariacica         2
# Colatina          1
# Fundão            1
# Name: NO_MUNICIPIO_ESC, dtype: int64

# %%
amostras.index
# Out:
# Index(['Serra', 'Vitória', 'Santa Teresa', 'Aracruz', 'Vila Velha',
#        'Cariacica', 'Colatina', 'Fundão'],
#       dtype='object')

# %%
amostragem = np.random.choice(a=[0,1],size=8, replace=True, p=[0.85, 0.15])

# %%
amostragem
# Out:
# array([0, 0, 0, 0, 0, 1, 0, 0])

# %%
amos_conglomerado = amostras.loc[amostragem == 1]

# %%
amos_conglomerado
# Out:
# Cariacica    2
# Name: NO_MUNICIPIO_ESC, dtype: int64

# %%
amos_conglomerado.shape
# Out:
# (1,)

# %%
amos_conglomerado.index
# Out:
# Index(['Cariacica'], dtype='object')

# %%
# selecionar o index apresentado no output anterior
amos_conglomerado = escolas_publicas.loc[escolas_publicas['NO_MUNICIPIO_ESC'].isin(['Cariacica'])]

# %%
amos_conglomerado
# Out:
#      NU_INSCRICAO FAIXA_ETARIA SEXO  ESTADO_CIVIL   RACA  NACIONALIDADE  \
# 2121     2,10E+11           18    F             1  preta              1
# 9447     2,10E+11           18    M             1  parda              1
#
#       TP_ST_CONCLUSAO   ESCOLA NO_MUNICIPIO_ESC NO_MUNICIPIO_PROVA  ...  \
# 2121                2  publica        Cariacica              Serra  ...
# 9447                2  publica        Cariacica              Serra  ...
#
#       NOTA_MT  TP_LINGUA  TP_STATUS_REDACAO  COMP1  COMP2  COMP3  COMP4  \
# 2121    357.9     ingles                4.0    0.0    0.0    0.0    0.0
# 9447    594.0     ingles                1.0  100.0  120.0   80.0  120.0
#
#       COMP5 NOTA_REDACAO  INTERNET
# 2121    0.0          0.0       sim
# 9447    0.0        420.0       sim
#
# [2 rows x 27 columns]
